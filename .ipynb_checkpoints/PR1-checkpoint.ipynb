# %% [markdown]
# # Práctica 1

# %% [markdown]
# Explicacion de la práctica

# %%
# Importamos las librerias necesarias para poder depurar el dataset
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
airbnbs = pd.read_csv('./DatasetsLab1/airbnb.csv', encoding='latin-1')
airbnbs
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
#            host_name neighbourhood_group       neighbourhood  latitude  \
# 0               John            Brooklyn          Kensington  40.64749
# 1           Jennifer           Manhattan             Midtown  40.75362
# 2          Elisabeth           Manhattan              Harlem  40.80902
# 3        LisaRoxanne            Brooklyn        Clinton Hill  40.68514
# 4              Laura           Manhattan         East Harlem  40.79851
# ...              ...                 ...                 ...       ...
# 48890        Sabrina            Brooklyn  Bedford-Stuyvesant  40.67853
# 48891        Marisol            Brooklyn            Bushwick  40.70184
# 48892  Ilgar & Aysel           Manhattan              Harlem  40.81475
# 48893            Taz           Manhattan      Hell's Kitchen  40.75751
# 48894     Christophe           Manhattan      Hell's Kitchen  40.76404
#
#        longitude        room_type  price  minimum_nights  number_of_reviews  \
# 0      -73.97237     Private room    149               1                  9
# 1      -73.98377  Entire home/apt    225               1                 45
# 2      -73.94190     Private room    150               3                  0
# 3      -73.95976  Entire home/apt     89               1                270
# 4      -73.94399  Entire home/apt     80              10                  9
# ...          ...              ...    ...             ...                ...
# 48890  -73.94995     Private room     70               2                  0
# 48891  -73.93317     Private room     40               4                  0
# 48892  -73.94867  Entire home/apt    115              10                  0
# 48893  -73.99112      Shared room     55               1                  0
# 48894  -73.98933     Private room     90               7                  0
#
#       last_review  reviews_per_month  calculated_host_listings_count  \
# 0      2018-10-19               0.21                               6
# 1      2019-05-21               0.38                               2
# 2             NaN                NaN                               1
# 3      2019-07-05               4.64                               1
# 4      2018-11-19               0.10                               1
# ...           ...                ...                             ...
# 48890         NaN                NaN                               2
# 48891         NaN                NaN                               2
# 48892         NaN                NaN                               1
# 48893         NaN                NaN                               6
# 48894         NaN                NaN                               1
#
#        availability_365
# 0                   365
# 1                   355
# 2                   365
# 3                   194
# 4                     0
# ...                 ...
# 48890                 9
# 48891                36
# 48892                27
# 48893                 2
# 48894                23
#
# [48895 rows x 16 columns]

# %% [markdown]
# ### Eliminamos los valores NaN

# %%
airbnbs = airbnbs.dropna()
airbnbs
# Out:
#              id                                              name    host_id  \
# 0          2539                Clean & quiet apt home by the park       2787
# 1          2595                             Skylit Midtown Castle       2845
# 3          3831                   Cozy Entire Floor of Brownstone       4869
# 4          5022  Entire Apt: Spacious Studio/Loft by central park       7192
# 5          5099         Large Cozy 1 BR Apartment In Midtown East       7322
# ...         ...                                               ...        ...
# 48782  36425863        Lovely Privet Bedroom with Privet Restroom   83554966
# 48790  36427429                          No.2 with queen size bed  257683179
# 48799  36438336                                   Seas The Moment  211644523
# 48805  36442252                     1B-1B apartment near by Metro  273841667
# 48852  36455809           Cozy Private Room in Bushwick, Brooklyn   74162901
#
#          host_name neighbourhood_group    neighbourhood  latitude  longitude  \
# 0             John            Brooklyn       Kensington  40.64749  -73.97237
# 1         Jennifer           Manhattan          Midtown  40.75362  -73.98377
# 3      LisaRoxanne            Brooklyn     Clinton Hill  40.68514  -73.95976
# 4            Laura           Manhattan      East Harlem  40.79851  -73.94399
# 5            Chris           Manhattan      Murray Hill  40.74767  -73.97500
# ...            ...                 ...              ...       ...        ...
# 48782        Rusaa           Manhattan  Upper East Side  40.78099  -73.95366
# 48790       HâAi              Queens         Flushing  40.75104  -73.81459
# 48799          Ben       Staten Island      Great Kills  40.54179  -74.14275
# 48805       Blaine               Bronx       Mott Haven  40.80787  -73.92400
# 48852    Christine            Brooklyn         Bushwick  40.69805  -73.92801
#
#              room_type  price  minimum_nights  number_of_reviews last_review  \
# 0         Private room    149               1                  9  2018-10-19
# 1      Entire home/apt    225               1                 45  2019-05-21
# 3      Entire home/apt     89               1                270  2019-07-05
# 4      Entire home/apt     80              10                  9  2018-11-19
# 5      Entire home/apt    200               3                 74  2019-06-22
# ...                ...    ...             ...                ...         ...
# 48782     Private room    129               1                  1  2019-07-07
# 48790     Private room     45               1                  1  2019-07-07
# 48799     Private room    235               1                  1  2019-07-07
# 48805  Entire home/apt    100               1                  2  2019-07-07
# 48852     Private room     30               1                  1  2019-07-08
#
#        reviews_per_month  calculated_host_listings_count  availability_365
# 0                   0.21                               6               365
# 1                   0.38                               2               355
# 3                   4.64                               1               194
# 4                   0.10                               1                 0
# 5                   0.59                               1               129
# ...                  ...                             ...               ...
# 48782               1.00                               1               147
# 48790               1.00                               6               339
# 48799               1.00                               1                87
# 48805               2.00                               1                40
# 48852               1.00                               1                 1
#
# [38821 rows x 16 columns]

# %% [markdown]
# ### Eliminamos valores duplicados

# %%
airbnbs = airbnbs.drop_duplicates() #elimina las filas duplicadas
airbnbs
# Out:
#              id                                              name    host_id  \
# 0          2539                Clean & quiet apt home by the park       2787
# 1          2595                             Skylit Midtown Castle       2845
# 3          3831                   Cozy Entire Floor of Brownstone       4869
# 4          5022  Entire Apt: Spacious Studio/Loft by central park       7192
# 5          5099         Large Cozy 1 BR Apartment In Midtown East       7322
# ...         ...                                               ...        ...
# 48782  36425863        Lovely Privet Bedroom with Privet Restroom   83554966
# 48790  36427429                          No.2 with queen size bed  257683179
# 48799  36438336                                   Seas The Moment  211644523
# 48805  36442252                     1B-1B apartment near by Metro  273841667
# 48852  36455809           Cozy Private Room in Bushwick, Brooklyn   74162901
#
#          host_name neighbourhood_group    neighbourhood  latitude  longitude  \
# 0             John            Brooklyn       Kensington  40.64749  -73.97237
# 1         Jennifer           Manhattan          Midtown  40.75362  -73.98377
# 3      LisaRoxanne            Brooklyn     Clinton Hill  40.68514  -73.95976
# 4            Laura           Manhattan      East Harlem  40.79851  -73.94399
# 5            Chris           Manhattan      Murray Hill  40.74767  -73.97500
# ...            ...                 ...              ...       ...        ...
# 48782        Rusaa           Manhattan  Upper East Side  40.78099  -73.95366
# 48790       HâAi              Queens         Flushing  40.75104  -73.81459
# 48799          Ben       Staten Island      Great Kills  40.54179  -74.14275
# 48805       Blaine               Bronx       Mott Haven  40.80787  -73.92400
# 48852    Christine            Brooklyn         Bushwick  40.69805  -73.92801
#
#              room_type  price  minimum_nights  number_of_reviews last_review  \
# 0         Private room    149               1                  9  2018-10-19
# 1      Entire home/apt    225               1                 45  2019-05-21
# 3      Entire home/apt     89               1                270  2019-07-05
# 4      Entire home/apt     80              10                  9  2018-11-19
# 5      Entire home/apt    200               3                 74  2019-06-22
# ...                ...    ...             ...                ...         ...
# 48782     Private room    129               1                  1  2019-07-07
# 48790     Private room     45               1                  1  2019-07-07
# 48799     Private room    235               1                  1  2019-07-07
# 48805  Entire home/apt    100               1                  2  2019-07-07
# 48852     Private room     30               1                  1  2019-07-08
#
#        reviews_per_month  calculated_host_listings_count  availability_365
# 0                   0.21                               6               365
# 1                   0.38                               2               355
# 3                   4.64                               1               194
# 4                   0.10                               1                 0
# 5                   0.59                               1               129
# ...                  ...                             ...               ...
# 48782               1.00                               1               147
# 48790               1.00                               6               339
# 48799               1.00                               1                87
# 48805               2.00                               1                40
# 48852               1.00                               1                 1
#
# [38821 rows x 16 columns]

# %% [markdown]
# ### Filtramos las columnas que nos interesen de todo el dataframe

# %% [markdown]
# La columna de reseñas por mes, las dividimos en 3 rangos iguales, después dependiendo del valor concreto que tenga cada apartamento se le asignarán las etiquetas: “Baja”, “Media” y ”Alta”.

# %%
columnaResenasMes = airbnbs[["reviews_per_month"]] #sacamos solo la columna de reseñas por mes
columnaResenasMes.head(10) #mostramos las 10 primera para confirmar que lo hemos hecho bien
# Out:
#     reviews_per_month
# 0                0.21
# 1                0.38
# 3                4.64
# 4                0.10
# 5                0.59
# 6                0.40
# 7                3.47
# 8                0.99
# 9                1.33
# 10               0.43

# %% [markdown]
# Para saber como dividir en 3 grupos los valores, vamos a ver cual es el valor maximo y cual es el valor minimo de esta columna.

# %%
maxResenas = columnaResenasMes.max()
print(str(maxResenas))
minResenas = columnaResenasMes.min()
print(str(minResenas))
# Out:
# reviews_per_month    58.5
# dtype: float64
# reviews_per_month    0.01
# dtype: float64

# %% [markdown]
# Dividimos 58.5 entre tres para dividir por grupos

# %%
maxResenas/3
# Out:
# reviews_per_month    19.5
# dtype: float64

# %% [markdown]
# ##### Calidad baja iria de 0 a 19.5
# ##### Calidad media iria de 19.5 a 39
# ##### Calidad alta iria de 39 a 58.5
# ### Creamos otra columna, con la calidad, que añadiremos "Baja" "Media" y "Alta" según los valores mostrados arriba

# %%
#for index in range(columnaResenasMes.shape)):
  #  print(index)
airbnbs["Calidad"] = "None"
airbnbs
# Out:
#              id                                              name    host_id  \
# 0          2539                Clean & quiet apt home by the park       2787
# 1          2595                             Skylit Midtown Castle       2845
# 3          3831                   Cozy Entire Floor of Brownstone       4869
# 4          5022  Entire Apt: Spacious Studio/Loft by central park       7192
# 5          5099         Large Cozy 1 BR Apartment In Midtown East       7322
# ...         ...                                               ...        ...
# 48782  36425863        Lovely Privet Bedroom with Privet Restroom   83554966
# 48790  36427429                          No.2 with queen size bed  257683179
# 48799  36438336                                   Seas The Moment  211644523
# 48805  36442252                     1B-1B apartment near by Metro  273841667
# 48852  36455809           Cozy Private Room in Bushwick, Brooklyn   74162901
#
#          host_name neighbourhood_group    neighbourhood  latitude  longitude  \
# 0             John            Brooklyn       Kensington  40.64749  -73.97237
# 1         Jennifer           Manhattan          Midtown  40.75362  -73.98377
# 3      LisaRoxanne            Brooklyn     Clinton Hill  40.68514  -73.95976
# 4            Laura           Manhattan      East Harlem  40.79851  -73.94399
# 5            Chris           Manhattan      Murray Hill  40.74767  -73.97500
# ...            ...                 ...              ...       ...        ...
# 48782        Rusaa           Manhattan  Upper East Side  40.78099  -73.95366
# 48790       HâAi              Queens         Flushing  40.75104  -73.81459
# 48799          Ben       Staten Island      Great Kills  40.54179  -74.14275
# 48805       Blaine               Bronx       Mott Haven  40.80787  -73.92400
# 48852    Christine            Brooklyn         Bushwick  40.69805  -73.92801
#
#              room_type  price  minimum_nights  number_of_reviews last_review  \
# 0         Private room    149               1                  9  2018-10-19
# 1      Entire home/apt    225               1                 45  2019-05-21
# 3      Entire home/apt     89               1                270  2019-07-05
# 4      Entire home/apt     80              10                  9  2018-11-19
# 5      Entire home/apt    200               3                 74  2019-06-22
# ...                ...    ...             ...                ...         ...
# 48782     Private room    129               1                  1  2019-07-07
# 48790     Private room     45               1                  1  2019-07-07
# 48799     Private room    235               1                  1  2019-07-07
# 48805  Entire home/apt    100               1                  2  2019-07-07
# 48852     Private room     30               1                  1  2019-07-08
#
#        reviews_per_month  calculated_host_listings_count  availability_365  \
# 0                   0.21                               6               365
# 1                   0.38                               2               355
# 3                   4.64                               1               194
# 4                   0.10                               1                 0
# 5                   0.59                               1               129
# ...                  ...                             ...               ...
# 48782               1.00                               1               147
# 48790               1.00                               6               339
# 48799               1.00                               1                87
# 48805               2.00                               1                40
# 48852               1.00                               1                 1
#
#       Calidad
# 0        None
# 1        None
# 3        None
# 4        None
# 5        None
# ...       ...
# 48782    None
# 48790    None
# 48799    None
# 48805    None
# 48852    None
#
# [38821 rows x 17 columns]

# %%
airbnbs[["reviews_per_month", "Calidad"]]
airbnbs.dropna()
# Out:
#              id                                              name    host_id  \
# 0          2539                Clean & quiet apt home by the park       2787
# 1          2595                             Skylit Midtown Castle       2845
# 3          3831                   Cozy Entire Floor of Brownstone       4869
# 4          5022  Entire Apt: Spacious Studio/Loft by central park       7192
# 5          5099         Large Cozy 1 BR Apartment In Midtown East       7322
# ...         ...                                               ...        ...
# 48782  36425863        Lovely Privet Bedroom with Privet Restroom   83554966
# 48790  36427429                          No.2 with queen size bed  257683179
# 48799  36438336                                   Seas The Moment  211644523
# 48805  36442252                     1B-1B apartment near by Metro  273841667
# 48852  36455809           Cozy Private Room in Bushwick, Brooklyn   74162901
#
#          host_name neighbourhood_group    neighbourhood  latitude  longitude  \
# 0             John            Brooklyn       Kensington  40.64749  -73.97237
# 1         Jennifer           Manhattan          Midtown  40.75362  -73.98377
# 3      LisaRoxanne            Brooklyn     Clinton Hill  40.68514  -73.95976
# 4            Laura           Manhattan      East Harlem  40.79851  -73.94399
# 5            Chris           Manhattan      Murray Hill  40.74767  -73.97500
# ...            ...                 ...              ...       ...        ...
# 48782        Rusaa           Manhattan  Upper East Side  40.78099  -73.95366
# 48790       HâAi              Queens         Flushing  40.75104  -73.81459
# 48799          Ben       Staten Island      Great Kills  40.54179  -74.14275
# 48805       Blaine               Bronx       Mott Haven  40.80787  -73.92400
# 48852    Christine            Brooklyn         Bushwick  40.69805  -73.92801
#
#              room_type  price  minimum_nights  number_of_reviews last_review  \
# 0         Private room    149               1                  9  2018-10-19
# 1      Entire home/apt    225               1                 45  2019-05-21
# 3      Entire home/apt     89               1                270  2019-07-05
# 4      Entire home/apt     80              10                  9  2018-11-19
# 5      Entire home/apt    200               3                 74  2019-06-22
# ...                ...    ...             ...                ...         ...
# 48782     Private room    129               1                  1  2019-07-07
# 48790     Private room     45               1                  1  2019-07-07
# 48799     Private room    235               1                  1  2019-07-07
# 48805  Entire home/apt    100               1                  2  2019-07-07
# 48852     Private room     30               1                  1  2019-07-08
#
#        reviews_per_month  calculated_host_listings_count  availability_365  \
# 0                   0.21                               6               365
# 1                   0.38                               2               355
# 3                   4.64                               1               194
# 4                   0.10                               1                 0
# 5                   0.59                               1               129
# ...                  ...                             ...               ...
# 48782               1.00                               1               147
# 48790               1.00                               6               339
# 48799               1.00                               1                87
# 48805               2.00                               1                40
# 48852               1.00                               1                 1
#
#       Calidad
# 0        None
# 1        None
# 3        None
# 4        None
# 5        None
# ...       ...
# 48782    None
# 48790    None
# 48799    None
# 48805    None
# 48852    None
#
# [38821 rows x 17 columns]

# %%
for i, items in enumerate(airbnbs["reviews_per_month"].values):
    if items < 19.5:
        airbnbs.loc[i, "Calidad"] = "Baja"
    elif items >= 19.5 and items < 39: 
        airbnbs.loc[i, "Calidad" ] = "Media"
    elif items >= 39: 
        airbnbs.loc[i, "Calidad" ] = "Alta"
    
airbnbs.dropna()
airbnbs
# Out:
#            id                                              name  host_id  \
# 0      2539.0                Clean & quiet apt home by the park   2787.0
# 1      2595.0                             Skylit Midtown Castle   2845.0
# 3      3831.0                   Cozy Entire Floor of Brownstone   4869.0
# 4      5022.0  Entire Apt: Spacious Studio/Loft by central park   7192.0
# 5      5099.0         Large Cozy 1 BR Apartment In Midtown East   7322.0
# ...       ...                                               ...      ...
# 38811     NaN                                               NaN      NaN
# 38813     NaN                                               NaN      NaN
# 38814     NaN                                               NaN      NaN
# 38818     NaN                                               NaN      NaN
# 38819     NaN                                               NaN      NaN
#
#          host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0             John            Brooklyn    Kensington  40.64749  -73.97237
# 1         Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 3      LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4            Laura           Manhattan   East Harlem  40.79851  -73.94399
# 5            Chris           Manhattan   Murray Hill  40.74767  -73.97500
# ...            ...                 ...           ...       ...        ...
# 38811          NaN                 NaN           NaN       NaN        NaN
# 38813          NaN                 NaN           NaN       NaN        NaN
# 38814          NaN                 NaN           NaN       NaN        NaN
# 38818          NaN                 NaN           NaN       NaN        NaN
# 38819          NaN                 NaN           NaN       NaN        NaN
#
#              room_type  price  minimum_nights  number_of_reviews last_review  \
# 0         Private room  149.0             1.0                9.0  2018-10-19
# 1      Entire home/apt  225.0             1.0               45.0  2019-05-21
# 3      Entire home/apt   89.0             1.0              270.0  2019-07-05
# 4      Entire home/apt   80.0            10.0                9.0  2018-11-19
# 5      Entire home/apt  200.0             3.0               74.0  2019-06-22
# ...                ...    ...             ...                ...         ...
# 38811              NaN    NaN             NaN                NaN         NaN
# 38813              NaN    NaN             NaN                NaN         NaN
# 38814              NaN    NaN             NaN                NaN         NaN
# 38818              NaN    NaN             NaN                NaN         NaN
# 38819              NaN    NaN             NaN                NaN         NaN
#
#        reviews_per_month  calculated_host_listings_count  availability_365  \
# 0                   0.21                             6.0             365.0
# 1                   0.38                             2.0             355.0
# 3                   4.64                             1.0             194.0
# 4                   0.10                             1.0               0.0
# 5                   0.59                             1.0             129.0
# ...                  ...                             ...               ...
# 38811                NaN                             NaN               NaN
# 38813                NaN                             NaN               NaN
# 38814                NaN                             NaN               NaN
# 38818                NaN                             NaN               NaN
# 38819                NaN                             NaN               NaN
#
#       Calidad
# 0        Baja
# 1        Baja
# 3        Baja
# 4        Baja
# 5        Baja
# ...       ...
# 38811    Baja
# 38813    Baja
# 38814    Baja
# 38818    Baja
# 38819    Baja
#
# [45150 rows x 17 columns]

# %% [markdown]
#
# ### Ya tenemos la columna Calidad creada, ahora vamos a hacer lo mismo con la disponibilidad

# %% [markdown]
# La columna de disponibilidad, las dividimos en 3 rangos iguales, después dependiendo del valor concreto que tenga cada apartamento se le asignarán las etiquetas: "Poco Disponnible", "Disponible normalmemte", "Altamente disponible"
# Como hay 365 dias, dividimos los rangos en 122
# de 0 a 122: poca dispoibilidad
# de 122 a 244: Media disponibilidad
# de 224 a 365: alta

# %%
airbnbs["Disponibilidad"] = ""
airbnbs
# Out:
#            id                                              name  host_id  \
# 0      2539.0                Clean & quiet apt home by the park   2787.0
# 1      2595.0                             Skylit Midtown Castle   2845.0
# 3      3831.0                   Cozy Entire Floor of Brownstone   4869.0
# 4      5022.0  Entire Apt: Spacious Studio/Loft by central park   7192.0
# 5      5099.0         Large Cozy 1 BR Apartment In Midtown East   7322.0
# ...       ...                                               ...      ...
# 38811     NaN                                               NaN      NaN
# 38813     NaN                                               NaN      NaN
# 38814     NaN                                               NaN      NaN
# 38818     NaN                                               NaN      NaN
# 38819     NaN                                               NaN      NaN
#
#          host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0             John            Brooklyn    Kensington  40.64749  -73.97237
# 1         Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 3      LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4            Laura           Manhattan   East Harlem  40.79851  -73.94399
# 5            Chris           Manhattan   Murray Hill  40.74767  -73.97500
# ...            ...                 ...           ...       ...        ...
# 38811          NaN                 NaN           NaN       NaN        NaN
# 38813          NaN                 NaN           NaN       NaN        NaN
# 38814          NaN                 NaN           NaN       NaN        NaN
# 38818          NaN                 NaN           NaN       NaN        NaN
# 38819          NaN                 NaN           NaN       NaN        NaN
#
#              room_type  price  minimum_nights  number_of_reviews last_review  \
# 0         Private room  149.0             1.0                9.0  2018-10-19
# 1      Entire home/apt  225.0             1.0               45.0  2019-05-21
# 3      Entire home/apt   89.0             1.0              270.0  2019-07-05
# 4      Entire home/apt   80.0            10.0                9.0  2018-11-19
# 5      Entire home/apt  200.0             3.0               74.0  2019-06-22
# ...                ...    ...             ...                ...         ...
# 38811              NaN    NaN             NaN                NaN         NaN
# 38813              NaN    NaN             NaN                NaN         NaN
# 38814              NaN    NaN             NaN                NaN         NaN
# 38818              NaN    NaN             NaN                NaN         NaN
# 38819              NaN    NaN             NaN                NaN         NaN
#
#        reviews_per_month  calculated_host_listings_count  availability_365  \
# 0                   0.21                             6.0             365.0
# 1                   0.38                             2.0             355.0
# 3                   4.64                             1.0             194.0
# 4                   0.10                             1.0               0.0
# 5                   0.59                             1.0             129.0
# ...                  ...                             ...               ...
# 38811                NaN                             NaN               NaN
# 38813                NaN                             NaN               NaN
# 38814                NaN                             NaN               NaN
# 38818                NaN                             NaN               NaN
# 38819                NaN                             NaN               NaN
#
#       Calidad Disponibilidad
# 0        Baja
# 1        Baja
# 3        Baja
# 4        Baja
# 5        Baja
# ...       ...            ...
# 38811    Baja
# 38813    Baja
# 38814    Baja
# 38818    Baja
# 38819    Baja
#
# [45150 rows x 18 columns]

# %% [markdown]
# ### Columna Disponibilidad vacia creada, la rellenamos con datos

# %%
i = 0
for items in airbnbs["availability_365"].values:
    #print("iteracion " + str(i))
    #print("Reviews per Month " + str(items))
    if items < 122:
        airbnbs.loc[i, "Disponibilidad"] = "Poco disponible"
        #print("Calidad buena")
        #print(items)
    if items > 121 and items < 244: 
        airbnbs.loc[i, "Disponibilidad" ] = "Disponible normalmente"
        #print(items)
    if items > 243: 
        airbnbs.loc[i, "Disponibilidad" ] = "Altamente disponible"
        #print(items)
    i = i +1
airbnbs
# Out:
#            id                                              name  host_id  \
# 0      2539.0                Clean & quiet apt home by the park   2787.0
# 1      2595.0                             Skylit Midtown Castle   2845.0
# 3      3831.0                   Cozy Entire Floor of Brownstone   4869.0
# 4      5022.0  Entire Apt: Spacious Studio/Loft by central park   7192.0
# 5      5099.0         Large Cozy 1 BR Apartment In Midtown East   7322.0
# ...       ...                                               ...      ...
# 38811     NaN                                               NaN      NaN
# 38813     NaN                                               NaN      NaN
# 38814     NaN                                               NaN      NaN
# 38818     NaN                                               NaN      NaN
# 38819     NaN                                               NaN      NaN
#
#          host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0             John            Brooklyn    Kensington  40.64749  -73.97237
# 1         Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 3      LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4            Laura           Manhattan   East Harlem  40.79851  -73.94399
# 5            Chris           Manhattan   Murray Hill  40.74767  -73.97500
# ...            ...                 ...           ...       ...        ...
# 38811          NaN                 NaN           NaN       NaN        NaN
# 38813          NaN                 NaN           NaN       NaN        NaN
# 38814          NaN                 NaN           NaN       NaN        NaN
# 38818          NaN                 NaN           NaN       NaN        NaN
# 38819          NaN                 NaN           NaN       NaN        NaN
#
#              room_type  price  minimum_nights  number_of_reviews last_review  \
# 0         Private room  149.0             1.0                9.0  2018-10-19
# 1      Entire home/apt  225.0             1.0               45.0  2019-05-21
# 3      Entire home/apt   89.0             1.0              270.0  2019-07-05
# 4      Entire home/apt   80.0            10.0                9.0  2018-11-19
# 5      Entire home/apt  200.0             3.0               74.0  2019-06-22
# ...                ...    ...             ...                ...         ...
# 38811              NaN    NaN             NaN                NaN         NaN
# 38813              NaN    NaN             NaN                NaN         NaN
# 38814              NaN    NaN             NaN                NaN         NaN
# 38818              NaN    NaN             NaN                NaN         NaN
# 38819              NaN    NaN             NaN                NaN         NaN
#
#        reviews_per_month  calculated_host_listings_count  availability_365  \
# 0                   0.21                             6.0             365.0
# 1                   0.38                             2.0             355.0
# 3                   4.64                             1.0             194.0
# 4                   0.10                             1.0               0.0
# 5                   0.59                             1.0             129.0
# ...                  ...                             ...               ...
# 38811                NaN                             NaN               NaN
# 38813                NaN                             NaN               NaN
# 38814                NaN                             NaN               NaN
# 38818                NaN                             NaN               NaN
# 38819                NaN                             NaN               NaN
#
#       Calidad          Disponibilidad
# 0        Baja    Altamente disponible
# 1        Baja    Altamente disponible
# 3        Baja         Poco disponible
# 4        Baja  Disponible normalmente
# 5        Baja         Poco disponible
# ...       ...                     ...
# 38811    Baja         Poco disponible
# 38813    Baja         Poco disponible
# 38814    Baja         Poco disponible
# 38818    Baja         Poco disponible
# 38819    Baja         Poco disponible
#
# [45150 rows x 18 columns]

# %% [markdown]
# ### Clasificamos apartamentos. Creamos una columna Clasificacion

# %%
airbnbs["Clasificacion"] = ""
airbnbs
# Out:
#            id                                              name  host_id  \
# 0      2539.0                Clean & quiet apt home by the park   2787.0
# 1      2595.0                             Skylit Midtown Castle   2845.0
# 3      3831.0                   Cozy Entire Floor of Brownstone   4869.0
# 4      5022.0  Entire Apt: Spacious Studio/Loft by central park   7192.0
# 5      5099.0         Large Cozy 1 BR Apartment In Midtown East   7322.0
# ...       ...                                               ...      ...
# 38811     NaN                                               NaN      NaN
# 38813     NaN                                               NaN      NaN
# 38814     NaN                                               NaN      NaN
# 38818     NaN                                               NaN      NaN
# 38819     NaN                                               NaN      NaN
#
#          host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0             John            Brooklyn    Kensington  40.64749  -73.97237
# 1         Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 3      LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4            Laura           Manhattan   East Harlem  40.79851  -73.94399
# 5            Chris           Manhattan   Murray Hill  40.74767  -73.97500
# ...            ...                 ...           ...       ...        ...
# 38811          NaN                 NaN           NaN       NaN        NaN
# 38813          NaN                 NaN           NaN       NaN        NaN
# 38814          NaN                 NaN           NaN       NaN        NaN
# 38818          NaN                 NaN           NaN       NaN        NaN
# 38819          NaN                 NaN           NaN       NaN        NaN
#
#              room_type  price  minimum_nights  number_of_reviews last_review  \
# 0         Private room  149.0             1.0                9.0  2018-10-19
# 1      Entire home/apt  225.0             1.0               45.0  2019-05-21
# 3      Entire home/apt   89.0             1.0              270.0  2019-07-05
# 4      Entire home/apt   80.0            10.0                9.0  2018-11-19
# 5      Entire home/apt  200.0             3.0               74.0  2019-06-22
# ...                ...    ...             ...                ...         ...
# 38811              NaN    NaN             NaN                NaN         NaN
# 38813              NaN    NaN             NaN                NaN         NaN
# 38814              NaN    NaN             NaN                NaN         NaN
# 38818              NaN    NaN             NaN                NaN         NaN
# 38819              NaN    NaN             NaN                NaN         NaN
#
#        reviews_per_month  calculated_host_listings_count  availability_365  \
# 0                   0.21                             6.0             365.0
# 1                   0.38                             2.0             355.0
# 3                   4.64                             1.0             194.0
# 4                   0.10                             1.0               0.0
# 5                   0.59                             1.0             129.0
# ...                  ...                             ...               ...
# 38811                NaN                             NaN               NaN
# 38813                NaN                             NaN               NaN
# 38814                NaN                             NaN               NaN
# 38818                NaN                             NaN               NaN
# 38819                NaN                             NaN               NaN
#
#       Calidad          Disponibilidad Clasificacion
# 0        Baja    Altamente disponible
# 1        Baja    Altamente disponible
# 3        Baja         Poco disponible
# 4        Baja  Disponible normalmente
# 5        Baja         Poco disponible
# ...       ...                     ...           ...
# 38811    Baja         Poco disponible
# 38813    Baja         Poco disponible
# 38814    Baja         Poco disponible
# 38818    Baja         Poco disponible
# 38819    Baja         Poco disponible
#
# [45150 rows x 19 columns]

# %% [markdown]
# ### Rellenamos la columna de clasificacion

# %%
airbnbs.dropna()

for i, items in enumerate(airbnbs["Calidad"].values):
    #print("iteracion " + str(i))
    #print(airbnbs.loc[i, "Disponibilidad"])
    #print("Reviews pe Month " + str(items))
    #disponibilidad = airbnbs.loc[i, "Disponibilidad"]
    #print(disponibilidad)     
    #print(items)
    if i == 38823:
        break
    if items == "Baja" and airbnbs.loc[i, "Disponibilidad"] == "Poco disponible":
        airbnbs.loc[i, "Clasificacion"] = "Bueno"
        #print("Calidad buena")
        #print(airbnbs.items)
    if items == "Media" and airbnbs.loc[i, "Disponibilidad"] == "Poco disponible":
        airbnbs.loc[i, "Clasificacion"] = "Bueno"
        #print(airbnbs.items)
    if items == "Alta" and airbnbs.loc[i, "Disponibilidad"] == "Poco disponible":
        airbnbs.loc[i, "Clasificacion"] = "Muy Bueno"
        #print(airbnbs.items)
    if items == "Baja" and airbnbs.loc[i, "Disponibilidad"] == "Disponible normalmente":
        airbnbs.loc[i, "Clasificacion"] = "Regular"
        #print(airbnbs.items)
    if items == "Media" and airbnbs.loc[i, "Disponibilidad"] == "Disponible normalmente":
        airbnbs.loc[i, "Clasificacion"] = "Regular"
        #print(airbnbs.items)
    if items == "Alta" and airbnbs.loc[i, "Disponibilidad"] == "Disponible normalemnte":
        airbnbs.loc[i, "Clasificacion"] = "Bueno"
        #print(airbnbs.items)
    if items == "Baja" and airbnbs.loc[i, "Disponibilidad"] == "Altamente disponible":
        airbnbs.loc[i, "Clasificacion"] = "Malo"
        #print(airbnbs.items)
    if items == "Media" and airbnbs.loc[i, "Disponibilidad"] == "Altamente disponible":
        airbnbs.loc[i, "Clasificacion"] = "Malo"
        #print(airbnbs.items)
    if items == "Alta" and airbnbs.loc[i, "Disponibilidad"] == "Altamente disponible":
        airbnbs.loc[i, "Clasificacion"] = "Muy Malo"
        #print(airbnbs.items)
  
    #print()
airbnbs.head(20)
# Out:
#         id                                              name  host_id  \
# 0   2539.0                Clean & quiet apt home by the park   2787.0
# 1   2595.0                             Skylit Midtown Castle   2845.0
# 3   3831.0                   Cozy Entire Floor of Brownstone   4869.0
# 4   5022.0  Entire Apt: Spacious Studio/Loft by central park   7192.0
# 5   5099.0         Large Cozy 1 BR Apartment In Midtown East   7322.0
# 6   5121.0                                   BlissArtsSpace!   7356.0
# 7   5178.0                  Large Furnished Room Near B'way    8967.0
# 8   5203.0                Cozy Clean Guest Room - Family Apt   7490.0
# 9   5238.0                Cute & Cozy Lower East Side 1 bdrm   7549.0
# 10  5295.0                  Beautiful 1br on Upper West Side   7702.0
# 11  5441.0                   Central Manhattan/near Broadway   7989.0
# 12  5803.0    Lovely Room 1, Garden, Best Area, Legal rental   9744.0
# 13  6021.0  Wonderful Guest Bedroom in Manhattan for SINGLES  11528.0
# 14  6090.0                     West Village Nest - Superhost  11975.0
# 15  6848.0                  Only 2 stops to Manhattan studio  15991.0
# 16  7097.0                 Perfect for Your Parents + Garden  17571.0
# 17  7322.0                                   Chelsea Perfect  18946.0
# 18  7726.0   Hip Historic Brownstone Apartment with Backyard  20950.0
# 20  7801.0                  Sweet and Spacious Brooklyn Loft  21207.0
# 21  8024.0                    CBG CtyBGd HelpsHaiti rm#1:1-4  22486.0
#
#            host_name neighbourhood_group       neighbourhood  latitude  \
# 0               John            Brooklyn          Kensington  40.64749
# 1           Jennifer           Manhattan             Midtown  40.75362
# 3        LisaRoxanne            Brooklyn        Clinton Hill  40.68514
# 4              Laura           Manhattan         East Harlem  40.79851
# 5              Chris           Manhattan         Murray Hill  40.74767
# 6              Garon            Brooklyn  Bedford-Stuyvesant  40.68688
# 7           Shunichi           Manhattan      Hell's Kitchen  40.76489
# 8          MaryEllen           Manhattan     Upper West Side  40.80178
# 9                Ben           Manhattan           Chinatown  40.71344
# 10              Lena           Manhattan     Upper West Side  40.80316
# 11              Kate           Manhattan      Hell's Kitchen  40.76076
# 12            Laurie            Brooklyn         South Slope  40.66829
# 13           Claudio           Manhattan     Upper West Side  40.79826
# 14             Alina           Manhattan        West Village  40.73530
# 15     Allen & Irina            Brooklyn        Williamsburg  40.70837
# 16              Jane            Brooklyn         Fort Greene  40.69169
# 17              Doti           Manhattan             Chelsea  40.74192
# 18  Adam And Charity            Brooklyn       Crown Heights  40.67592
# 20             Chaya            Brooklyn        Williamsburg  40.71842
# 21             Lisel            Brooklyn          Park Slope  40.68069
#
#     longitude        room_type  price  minimum_nights  number_of_reviews  \
# 0   -73.97237     Private room  149.0             1.0                9.0
# 1   -73.98377  Entire home/apt  225.0             1.0               45.0
# 3   -73.95976  Entire home/apt   89.0             1.0              270.0
# 4   -73.94399  Entire home/apt   80.0            10.0                9.0
# 5   -73.97500  Entire home/apt  200.0             3.0               74.0
# 6   -73.95596     Private room   60.0            45.0               49.0
# 7   -73.98493     Private room   79.0             2.0              430.0
# 8   -73.96723     Private room   79.0             2.0              118.0
# 9   -73.99037  Entire home/apt  150.0             1.0              160.0
# 10  -73.96545  Entire home/apt  135.0             5.0               53.0
# 11  -73.98867     Private room   85.0             2.0              188.0
# 12  -73.98779     Private room   89.0             4.0              167.0
# 13  -73.96113     Private room   85.0             2.0              113.0
# 14  -74.00525  Entire home/apt  120.0            90.0               27.0
# 15  -73.95352  Entire home/apt  140.0             2.0              148.0
# 16  -73.97185  Entire home/apt  215.0             2.0              198.0
# 17  -73.99501     Private room  140.0             1.0              260.0
# 18  -73.94694  Entire home/apt   99.0             3.0               53.0
# 20  -73.95718  Entire home/apt  299.0             3.0                9.0
# 21  -73.97706     Private room  130.0             2.0              130.0
#
#    last_review  reviews_per_month  calculated_host_listings_count  \
# 0   2018-10-19               0.21                             6.0
# 1   2019-05-21               0.38                             2.0
# 3   2019-07-05               4.64                             1.0
# 4   2018-11-19               0.10                             1.0
# 5   2019-06-22               0.59                             1.0
# 6   2017-10-05               0.40                             1.0
# 7   2019-06-24               3.47                             1.0
# 8   2017-07-21               0.99                             1.0
# 9   2019-06-09               1.33                             4.0
# 10  2019-06-22               0.43                             1.0
# 11  2019-06-23               1.50                             1.0
# 12  2019-06-24               1.34                             3.0
# 13  2019-07-05               0.91                             1.0
# 14  2018-10-31               0.22                             1.0
# 15  2019-06-29               1.20                             1.0
# 16  2019-06-28               1.72                             1.0
# 17  2019-07-01               2.12                             1.0
# 18  2019-06-22               4.44                             1.0
# 20  2011-12-28               0.07                             1.0
# 21  2019-07-01               1.09                             6.0
#
#     availability_365 Calidad          Disponibilidad Clasificacion
# 0              365.0    Baja    Altamente disponible          Malo
# 1              355.0    Baja    Altamente disponible          Malo
# 3              194.0    Baja         Poco disponible         Bueno
# 4                0.0    Baja  Disponible normalmente       Regular
# 5              129.0    Baja         Poco disponible         Bueno
# 6                0.0    Baja  Disponible normalmente       Regular
# 7              220.0    Baja         Poco disponible         Bueno
# 8                0.0    Baja  Disponible normalmente       Regular
# 9              188.0    Baja         Poco disponible         Bueno
# 10               6.0    Baja         Poco disponible         Bueno
# 11              39.0    Baja    Altamente disponible          Malo
# 12             314.0    Baja    Altamente disponible          Malo
# 13             333.0    Baja         Poco disponible         Bueno
# 14               0.0    Baja         Poco disponible         Bueno
# 15              46.0    Baja    Altamente disponible          Malo
# 16             321.0    Baja         Poco disponible         Bueno
# 17              12.0    Baja         Poco disponible         Bueno
# 18              21.0    Baja         Poco disponible         Bueno
# 20               0.0    Baja    Altamente disponible          Malo
# 21             347.0    Baja    Altamente disponible          Malo

# %% [markdown]
# ## Agrupamos por barrio para saber el número total de reseñas por barrio

# %%
resenas_por_barrio = airbnbs.groupby("neighbourhood")["number_of_reviews"].sum()
resenas_por_barrio
# Out:
# neighbourhood
# Allerton            1803.0
# Arden Heights         31.0
# Arrochar             307.0
# Arverne             2253.0
# Astoria            19310.0
#                     ...
# Willowbrook            9.0
# Windsor Terrace     4324.0
# Woodhaven           2792.0
# Woodlawn             484.0
# Woodside            5035.0
# Name: number_of_reviews, Length: 218, dtype: float64

# %% [markdown]
# ### ordenamos estos valores para sacar los 5 primeros

# %%
# Ordenar los resultados de forma descendente y tomar los primeros 5
top_5_barrios = resenas_por_barrio.sort_values(ascending=False).head(5)

# Imprimir los resultados
print(top_5_barrios)
# Out:
# neighbourhood
# Bedford-Stuyvesant    110352.0
# Williamsburg           85427.0
# Harlem                 75927.0
# Bushwick               52508.0
# Hell's Kitchen         49940.0
# Name: number_of_reviews, dtype: float64

# %% [markdown]
# ## Mostramos una grafica burbuja con los datos

# %%
grouped = airbnbs.groupby('neighbourhood')['Calidad'].value_counts()
# mostrar los resultados
#print(grouped)


# Crear un dataframe con los 5 barrios y su número total de reseñas
df = pd.DataFrame({'neighbourhood': top_5_barrios.index, 'Calidad': top_5_barrios.values})
barriosresenas = pd.merge(grouped, df, on="neighbourhood")
print(barriosresenas)


#print(df)
# Crear la figura y los ejes del diagrama de burbuja
fig, ax = plt.subplots()

# Crear el diagrama de burbuja
ax.scatter(x=barriosresenas['neighbourhood'], y=[1]*len(barriosresenas), s=barriosresenas['Calidad_x'], alpha=0.5)

# Configurar los ejes y el título
ax.set_xlabel('neighbourhood')
ax.set_ylabel('Número de reseñas')
ax.set_title('Top 5 barrios con más reseñas')

# Mostrar el diagrama
plt.show()
# Out:
#          neighbourhood  Calidad_x  Calidad_y
# 0   Bedford-Stuyvesant       2637   110352.0
# 1   Bedford-Stuyvesant        503   110352.0
# 2   Bedford-Stuyvesant          1   110352.0
# 3             Bushwick       1612    52508.0
# 4             Bushwick        329    52508.0
# 5             Bushwick          1    52508.0
# 6               Harlem       1919    75927.0
# 7               Harlem        285    75927.0
# 8       Hell's Kitchen       1130    49940.0
# 9       Hell's Kitchen        398    49940.0
# 10        Williamsburg       2716    85427.0
# 11        Williamsburg        446    85427.0
# 12        Williamsburg          1    85427.0

# %% [markdown]
# ### Podemos ver que la burbuja mas clara es la de calidad Baja, la del medio es calidad media, y la mas pequeña ( punto negro) es la calidad alta

# %% [markdown]
# #### podemos observar que de los barrios con mas reseñas, Hell´s Kitcken tiene el mayor numero de reseñas medias y el menor de reseñas bajas, podriamos decir que este es el mejor barrio para alquilar un airbnb es Hell´s Kitchen, los demas hay muchos mas airbnbs con calidad baja
