# %% [markdown]
# # Práctica 1

# %% [markdown]
# Explicacion de la práctica

# %%
# Importamos las librerias necesarias para poder depurar el dataset
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
airbnbs = pd.read_csv('./DatasetsLab1/airbnb.csv', encoding='latin-1')
airbnbs.head(10)
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
# 5  5099         Large Cozy 1 BR Apartment In Midtown East     7322
# 6  5121                                   BlissArtsSpace!     7356
# 7  5178                  Large Furnished Room Near B'way      8967
# 8  5203                Cozy Clean Guest Room - Family Apt     7490
# 9  5238                Cute & Cozy Lower East Side 1 bdrm     7549
#
#      host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 0         John            Brooklyn          Kensington  40.64749  -73.97237
# ...

# %% [markdown]
# ### Eliminamos los valores NaN

# %%
airbnbs = airbnbs.dropna()

# %% [markdown]
# ### Eliminamos valores duplicados

# %%
airbnbs = airbnbs.drop_duplicates() #elimina las filas duplicadas

# %% [markdown]
# ### Filtramos las columnas que nos interesen de todo el dataframe

# %% [markdown]
# La columna de reseñas por mes, las dividimos en 3 rangos iguales, después dependiendo del valor concreto que tenga cada apartamento se le asignarán las etiquetas: “Baja”, “Media” y ”Alta”.

# %%
columnaResenasMes = airbnbs[["reviews_per_month"]] #sacamos solo la columna de reseñas por mes
columnaResenasMes.head(10) #mostramos las 10 primera para confirmar que lo hemos hecho bien
# Out:
#     reviews_per_month
# 0                0.21
# 1                0.38
# 3                4.64
# 4                0.10
# 5                0.59
# 6                0.40
# 7                3.47
# 8                0.99
# 9                1.33
# 10               0.43

# %% [markdown]
# Para saber como dividir en 3 grupos los valores, vamos a ver cual es el valor maximo y cual es el valor minimo de esta columna.

# %%
maxResenas = columnaResenasMes.max()
print(str(maxResenas))
minResenas = columnaResenasMes.min()
print(str(minResenas))
# Out:
# reviews_per_month    58.5
# dtype: float64
# reviews_per_month    0.01
# dtype: float64

# %% [markdown]
# Dividimos 58.5 entre tres para dividir por grupos

# %%
maxResenas/3
# Out:
# reviews_per_month    19.5
# dtype: float64

# %% [markdown]
# ##### Calidad baja iria de 0 a 19.5
# ##### Calidad media iria de 19.5 a 39
# ##### Calidad alta iria de 39 a 58.5
# ### Creamos otra columna, con la calidad, que añadiremos "Baja" "Media" y "Alta" según los valores mostrados arriba

# %%
#for index in range(columnaResenasMes.shape)):
  #  print(index)
airbnbs["Calidad"] = "None"
airbnbs.head(10)
# Out:
#       id                                              name  host_id  \
# 0   2539                Clean & quiet apt home by the park     2787
# 1   2595                             Skylit Midtown Castle     2845
# 3   3831                   Cozy Entire Floor of Brownstone     4869
# 4   5022  Entire Apt: Spacious Studio/Loft by central park     7192
# 5   5099         Large Cozy 1 BR Apartment In Midtown East     7322
# 6   5121                                   BlissArtsSpace!     7356
# 7   5178                  Large Furnished Room Near B'way      8967
# 8   5203                Cozy Clean Guest Room - Family Apt     7490
# 9   5238                Cute & Cozy Lower East Side 1 bdrm     7549
# 10  5295                  Beautiful 1br on Upper West Side     7702
#
#       host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 0          John            Brooklyn          Kensington  40.64749  -73.97237
# ...

# %%
airbnbs[["reviews_per_month", "Calidad"]]
airbnbs.dropna().head(10)
# Out:
#       id                                              name  host_id  \
# 0   2539                Clean & quiet apt home by the park     2787
# 1   2595                             Skylit Midtown Castle     2845
# 3   3831                   Cozy Entire Floor of Brownstone     4869
# 4   5022  Entire Apt: Spacious Studio/Loft by central park     7192
# 5   5099         Large Cozy 1 BR Apartment In Midtown East     7322
# 6   5121                                   BlissArtsSpace!     7356
# 7   5178                  Large Furnished Room Near B'way      8967
# 8   5203                Cozy Clean Guest Room - Family Apt     7490
# 9   5238                Cute & Cozy Lower East Side 1 bdrm     7549
# 10  5295                  Beautiful 1br on Upper West Side     7702
#
#       host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 0          John            Brooklyn          Kensington  40.64749  -73.97237
# ...

# %%
for i, items in enumerate(airbnbs["reviews_per_month"].values):
    if items < 19.5:
        airbnbs.loc[i, "Calidad"] = "Baja"
    elif items >= 19.5 and items < 39: 
        airbnbs.loc[i, "Calidad" ] = "Media"
    elif items >= 39: 
        airbnbs.loc[i, "Calidad" ] = "Alta"
    
airbnbs.dropna()
airbnbs.head(10)
# Out:
#         id                                              name  host_id  \
# 0   2539.0                Clean & quiet apt home by the park   2787.0
# 1   2595.0                             Skylit Midtown Castle   2845.0
# 3   3831.0                   Cozy Entire Floor of Brownstone   4869.0
# 4   5022.0  Entire Apt: Spacious Studio/Loft by central park   7192.0
# 5   5099.0         Large Cozy 1 BR Apartment In Midtown East   7322.0
# 6   5121.0                                   BlissArtsSpace!   7356.0
# 7   5178.0                  Large Furnished Room Near B'way    8967.0
# 8   5203.0                Cozy Clean Guest Room - Family Apt   7490.0
# 9   5238.0                Cute & Cozy Lower East Side 1 bdrm   7549.0
# 10  5295.0                  Beautiful 1br on Upper West Side   7702.0
#
#       host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 0          John            Brooklyn          Kensington  40.64749  -73.97237
# ...

# %% [markdown]
#
# ### Ya tenemos la columna Calidad creada, ahora vamos a hacer lo mismo con la disponibilidad

# %% [markdown]
# La columna de disponibilidad, las dividimos en 3 rangos iguales, después dependiendo del valor concreto que tenga cada apartamento se le asignarán las etiquetas: "Poco Disponnible", "Disponible normalmemte", "Altamente disponible"
# Como hay 365 dias, dividimos los rangos en 122
# de 0 a 122: poca dispoibilidad
# de 122 a 244: Media disponibilidad
# de 224 a 365: alta

# %%
airbnbs["Disponibilidad"] = ""
airbnbs.head(10)
# Out:
#         id                                              name  host_id  \
# 0   2539.0                Clean & quiet apt home by the park   2787.0
# 1   2595.0                             Skylit Midtown Castle   2845.0
# 3   3831.0                   Cozy Entire Floor of Brownstone   4869.0
# 4   5022.0  Entire Apt: Spacious Studio/Loft by central park   7192.0
# 5   5099.0         Large Cozy 1 BR Apartment In Midtown East   7322.0
# 6   5121.0                                   BlissArtsSpace!   7356.0
# 7   5178.0                  Large Furnished Room Near B'way    8967.0
# 8   5203.0                Cozy Clean Guest Room - Family Apt   7490.0
# 9   5238.0                Cute & Cozy Lower East Side 1 bdrm   7549.0
# 10  5295.0                  Beautiful 1br on Upper West Side   7702.0
#
#       host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 0          John            Brooklyn          Kensington  40.64749  -73.97237
# ...

# %% [markdown]
# ### Columna Disponibilidad vacia creada, la rellenamos con datos

# %%
i = 0
for items in airbnbs["availability_365"].values:
    #print("iteracion " + str(i))
    #print("Reviews per Month " + str(items))
    if items < 122:
        airbnbs.loc[i, "Disponibilidad"] = "Poco disponible"
        #print("Calidad buena")
        #print(items)
    if items > 121 and items < 244: 
        airbnbs.loc[i, "Disponibilidad" ] = "Disponible normalmente"
        #print(items)
    if items > 243: 
        airbnbs.loc[i, "Disponibilidad" ] = "Altamente disponible"
        #print(items)
    i = i +1
airbnbs.head(10)
# Out:
#         id                                              name  host_id  \
# 0   2539.0                Clean & quiet apt home by the park   2787.0
# 1   2595.0                             Skylit Midtown Castle   2845.0
# 3   3831.0                   Cozy Entire Floor of Brownstone   4869.0
# 4   5022.0  Entire Apt: Spacious Studio/Loft by central park   7192.0
# 5   5099.0         Large Cozy 1 BR Apartment In Midtown East   7322.0
# 6   5121.0                                   BlissArtsSpace!   7356.0
# 7   5178.0                  Large Furnished Room Near B'way    8967.0
# 8   5203.0                Cozy Clean Guest Room - Family Apt   7490.0
# 9   5238.0                Cute & Cozy Lower East Side 1 bdrm   7549.0
# 10  5295.0                  Beautiful 1br on Upper West Side   7702.0
#
#       host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 0          John            Brooklyn          Kensington  40.64749  -73.97237
# ...

# %% [markdown]
# ### Clasificamos apartamentos. Creamos una columna Clasificacion

# %%
airbnbs["Clasificacion"] = ""
airbnbs.head(10)
# Out:
#         id                                              name  host_id  \
# 0   2539.0                Clean & quiet apt home by the park   2787.0
# 1   2595.0                             Skylit Midtown Castle   2845.0
# 3   3831.0                   Cozy Entire Floor of Brownstone   4869.0
# 4   5022.0  Entire Apt: Spacious Studio/Loft by central park   7192.0
# 5   5099.0         Large Cozy 1 BR Apartment In Midtown East   7322.0
# 6   5121.0                                   BlissArtsSpace!   7356.0
# 7   5178.0                  Large Furnished Room Near B'way    8967.0
# 8   5203.0                Cozy Clean Guest Room - Family Apt   7490.0
# 9   5238.0                Cute & Cozy Lower East Side 1 bdrm   7549.0
# 10  5295.0                  Beautiful 1br on Upper West Side   7702.0
#
#       host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 0          John            Brooklyn          Kensington  40.64749  -73.97237
# ...

# %% [markdown]
# ### Rellenamos la columna de clasificacion

# %%
airbnbs.dropna()

for i, items in enumerate(airbnbs["Calidad"].values):
    #print("iteracion " + str(i))
    #print(airbnbs.loc[i, "Disponibilidad"])
    #print("Reviews pe Month " + str(items))
    #disponibilidad = airbnbs.loc[i, "Disponibilidad"]
    #print(disponibilidad)     
    #print(items)
    if i == 38823:
        break
    if items == "Baja" and airbnbs.loc[i, "Disponibilidad"] == "Poco disponible":
        airbnbs.loc[i, "Clasificacion"] = "Bueno"
        #print("Calidad buena")
        #print(airbnbs.items)
    if items == "Media" and airbnbs.loc[i, "Disponibilidad"] == "Poco disponible":
        airbnbs.loc[i, "Clasificacion"] = "Bueno"
        #print(airbnbs.items)
    if items == "Alta" and airbnbs.loc[i, "Disponibilidad"] == "Poco disponible":
        airbnbs.loc[i, "Clasificacion"] = "Muy Bueno"
        #print(airbnbs.items)
    if items == "Baja" and airbnbs.loc[i, "Disponibilidad"] == "Disponible normalmente":
        airbnbs.loc[i, "Clasificacion"] = "Regular"
        #print(airbnbs.items)
    if items == "Media" and airbnbs.loc[i, "Disponibilidad"] == "Disponible normalmente":
        airbnbs.loc[i, "Clasificacion"] = "Regular"
        #print(airbnbs.items)
    if items == "Alta" and airbnbs.loc[i, "Disponibilidad"] == "Disponible normalemnte":
        airbnbs.loc[i, "Clasificacion"] = "Bueno"
        #print(airbnbs.items)
    if items == "Baja" and airbnbs.loc[i, "Disponibilidad"] == "Altamente disponible":
        airbnbs.loc[i, "Clasificacion"] = "Malo"
        #print(airbnbs.items)
    if items == "Media" and airbnbs.loc[i, "Disponibilidad"] == "Altamente disponible":
        airbnbs.loc[i, "Clasificacion"] = "Malo"
        #print(airbnbs.items)
    if items == "Alta" and airbnbs.loc[i, "Disponibilidad"] == "Altamente disponible":
        airbnbs.loc[i, "Clasificacion"] = "Muy Malo"
        #print(airbnbs.items)
  
    #print()
airbnbs.head(10)
# Out:
#         id                                              name  host_id  \
# 0   2539.0                Clean & quiet apt home by the park   2787.0
# 1   2595.0                             Skylit Midtown Castle   2845.0
# 3   3831.0                   Cozy Entire Floor of Brownstone   4869.0
# 4   5022.0  Entire Apt: Spacious Studio/Loft by central park   7192.0
# 5   5099.0         Large Cozy 1 BR Apartment In Midtown East   7322.0
# 6   5121.0                                   BlissArtsSpace!   7356.0
# 7   5178.0                  Large Furnished Room Near B'way    8967.0
# 8   5203.0                Cozy Clean Guest Room - Family Apt   7490.0
# 9   5238.0                Cute & Cozy Lower East Side 1 bdrm   7549.0
# 10  5295.0                  Beautiful 1br on Upper West Side   7702.0
#
#       host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 0          John            Brooklyn          Kensington  40.64749  -73.97237
# ...

# %% [markdown]
# ## Agrupamos por barrio para saber el número total de reseñas por barrio

# %%
resenas_por_barrio = airbnbs.groupby("neighbourhood")["number_of_reviews"].sum()
resenas_por_barrio
# Out:
# neighbourhood
# Allerton            1803.0
# Arden Heights         31.0
# Arrochar             307.0
# Arverne             2253.0
# Astoria            19310.0
#                     ...
# Willowbrook            9.0
# Windsor Terrace     4324.0
# Woodhaven           2792.0
# Woodlawn             484.0
# Woodside            5035.0
# Name: number_of_reviews, Length: 218, dtype: float64

# %% [markdown]
# ### ordenamos estos valores para sacar los 5 primeros

# %%
# Ordenar los resultados de forma descendente y tomar los primeros 5
top_5_barrios = resenas_por_barrio.sort_values(ascending=False).head(5)
# Imprimir los resultados
#print(top_5_barrios)
top_5_barrios.reset_index()
# Out:
#         neighbourhood  number_of_reviews
# 0  Bedford-Stuyvesant           110352.0
# 1        Williamsburg            85427.0
# 2              Harlem            75927.0
# 3            Bushwick            52508.0
# 4      Hell's Kitchen            49940.0

# %% [markdown]
# ## Mostramos una grafica burbuja con los datos

# %%
grouped = airbnbs.groupby('neighbourhood')['Calidad'].value_counts()
# mostrar los resultados
#print(grouped)


# Crear un dataframe con los 5 barrios y su número total de reseñas
df = pd.DataFrame({'neighbourhood': top_5_barrios.index, 'Calidad': top_5_barrios.values})
barriosresenas = pd.merge(grouped, df, on="neighbourhood")
#print(barriosresenas)


#print(df)
# Crear la figura y los ejes del diagrama de burbuja
fig, ax = plt.subplots()

# Crear el diagrama de burbuja
ax.scatter(x=barriosresenas['neighbourhood'], y=[1]*len(barriosresenas), s=barriosresenas['Calidad_x'], alpha=0.5)

# Configurar los ejes y el título
ax.set_xlabel('neighbourhood')
ax.set_ylabel('Calidad')
ax.set_title('Top 5 barrios con más reseñas')

# Mostrar el diagrama
plt.show()

# %% [markdown]
# ### Podemos ver que la burbuja mas clara es la de calidad Baja, la del medio es calidad media, y la mas pequeña ( punto negro) es la calidad alta

# %% [markdown]
# #### podemos observar que de los barrios con mas reseñas, Hell´s Kitcken tiene el mayor numero de reseñas medias y el menor de reseñas bajas, podriamos decir que este es el mejor barrio para alquilar un airbnb es Hell´s Kitchen, los demas hay muchos mas airbnbs con calidad baja

# %%
precios_medios = airbnbs.groupby(["neighbourhood", "room_type"])["price"].mean()
precios = precios_medios.reset_index()


# para el Barrio de harlem
preciosHarlem = precios.loc[precios['neighbourhood'] == "Harlem"]
#print(preciosHarlem["room_type"],preciosHarlem["price"])
plt.bar(preciosHarlem["room_type"],preciosHarlem["price"])
plt.title('Precios por tipo de habitacion en Harlem')
plt.xlabel('Tipos de Habitacion')
plt.ylabel('Precios')
plt.show()

# Para el barrio de Bedford-Stuyvesant
preciosBedfordStuyvesant = precios.loc[precios['neighbourhood'] == "Bedford-Stuyvesant"]
plt.bar(preciosBedfordStuyvesant["room_type"],preciosBedfordStuyvesant["price"])
plt.title('Precios por tipo de habitacion en Befdford')
plt.xlabel('Tipos de Habitacion')
plt.ylabel('Precios')
plt.show()


# Para el barrio de Hell´s Kitchen
preciosHK = precios.loc[precios['neighbourhood'] == "Hell's Kitchen"]
plt.bar(preciosHK["room_type"],preciosHK["price"])
plt.title('Precios por tipo de habitacion en Hells Kitchen')
plt.xlabel('Tipos de Habitacion')
plt.ylabel('Precios')
plt.show()


# Para el barrio de Bushwick
preciosBushwick = precios.loc[precios['neighbourhood'] == "Bushwick"]
plt.bar(preciosBushwick["room_type"],preciosBushwick["price"])
plt.title('Precios por tipo de habitacion en Bushwick')
plt.xlabel('Tipos de Habitacion')
plt.ylabel('Precios')
plt.show()

# Para el barrio de Williamsburg
preciosWilliamsburg = precios.loc[precios['neighbourhood'] == "Williamsburg"]
plt.bar(preciosWilliamsburg["room_type"],preciosWilliamsburg["price"])
plt.title('Precios por tipo de habitacion en Williamsburg')
plt.xlabel('Tipos de Habitacion')
plt.ylabel('Precios')
plt.show()

# %% [markdown]
# ### Conclusiones

# %% [markdown]
# # Diagrama de Cajas. Barrio Harlem.

# %%
print(preciosHarlem)
# Seleccionar la columna "precio" para crear el diagrama de cajas
price = preciosHarlem['price']
# Crear el diagrama de cajas
plt.boxplot(price)
# Añadir título y etiquetas de los ejes
plt.title('Diagrama de cajas. Barrio Harlem.')
# plt.xlabel('')
plt.ylabel('Precio')
# Mostrar el diagrama de cajas
plt.show()
# Out:
#     neighbourhood        room_type       price
# 226        Harlem  Entire home/apt  173.345848
# 227        Harlem     Private room   80.077519
# 228        Harlem      Shared room   72.114286

# %% [markdown]
# # Diagrama de Cajas. Barrio BedfordStuyvesant.

# %%
print(preciosBedfordStuyvesant)
# Seleccionar la columna "precio" para crear el diagrama de cajas
price1 = preciosBedfordStuyvesant['price']
# Crear el diagrama de cajas
plt.boxplot(price1)
# Añadir título y etiquetas de los ejes
plt.title('Diagrama de cajas. Barrio BedfordStuyvesant.')
# plt.xlabel('')
plt.ylabel('Precio')
# Mostrar el diagrama de cajas
plt.show()
# Out:
#          neighbourhood        room_type       price
# 29  Bedford-Stuyvesant  Entire home/apt  152.197497
# 30  Bedford-Stuyvesant     Private room   68.107230
# 31  Bedford-Stuyvesant      Shared room   39.521127

# %% [markdown]
# # Diagrama de Cajas. Barrio Hell's Kitchen.

# %%
print(preciosHK)
# Seleccionar la columna "precio" para crear el diagrama de cajas
price2 = preciosHK['price']
# Crear el diagrama de cajas
plt.boxplot(price2)
# Añadir título y etiquetas de los ejes
plt.title('Diagrama de cajas. Barrio Hells Kitchen.')
# plt.xlabel('')
plt.ylabel('Precio')
# Mostrar el diagrama de cajas
plt.show()
# Out:
#       neighbourhood        room_type       price
# 229  Hell's Kitchen  Entire home/apt  233.377401
# 230  Hell's Kitchen     Private room  127.374552
# 231  Hell's Kitchen      Shared room   81.541176

# %% [markdown]
# # Diagrama de Cajas. Barrio Bushwick.

# %%
print(preciosBushwick)
# Seleccionar la columna "precio" para crear el diagrama de cajas
price3 = preciosBushwick['price']
# Crear el diagrama de cajas
plt.boxplot(price3)
# Añadir título y etiquetas de los ejes
plt.title('Diagrama de cajas. Barrio Bushwick.')
# plt.xlabel('')
plt.ylabel('Precio')
# Mostrar el diagrama de cajas
plt.show()
# Out:
#    neighbourhood        room_type       price
# 63      Bushwick  Entire home/apt  141.564912
# 64      Bushwick     Private room   62.444611
# 65      Bushwick      Shared room   33.416667

# %% [markdown]
# # Diagrama de Cajas. Barrio Williamsburg.

# %%
print(preciosWilliamsburg)
# Seleccionar la columna "precio" para crear el diagrama de cajas
price4 = preciosWilliamsburg['price']
# Crear el diagrama de cajas
plt.boxplot(price4)
# Añadir título y etiquetas de los ejes
plt.title('Diagrama de cajas. Barrio Williamsburg.')
# plt.xlabel('')
plt.ylabel('Precio')
# Mostrar el diagrama de cajas
plt.show()
# Out:
#     neighbourhood        room_type       price
# 503  Williamsburg  Entire home/apt  197.137667
# 504  Williamsburg     Private room   83.480610
# 505  Williamsburg      Shared room   76.333333

# %% [markdown]
#  Tras hacer los diagramas de cajas de los 5 barrios más populares, podemos ver ciertas diferencias de precio entre el alquiler en distintos barrios.
#  Es decir, el barrio más barato para alquilar una habitación compartida es Bushwick, donde una habitación vale 33.41. A su vez, es el lugar más barato   para alquilar una habitación privada y un apartamento entero, con precios de 62.44 y 141.56 respectivamente.
#  Por tanto, podemos concluir que el barrio más barato para vivir es el barrio de Bushwick
#  Por otra parte, podemos ver que el precio para alquilar un apartamento entero en el barrio de Hell´s Kitchen es 233.37. A su vez, el precio de alquilar una habitación privada y una habitación compartida, es de 127.37 y 81.54 respectivamente.
#  Por tanto, podemos concluir que el barrio más caro para vivir es Hell´s Kitchen.
#  El precio de una habitación compartida en Hell´s Kitchen es más del doble de lo que vale una habitación compartida en Bushwick.
#
#
#  En todos los barrios la mitad de las casas valen más que el valor de la mediana y la otra mitad vale menos. Por tanto, por ejmplo en el barrio de Harlem la mitad de las casas cuestan más de 80, mientras que, la otra mitad cuesta menos de 80.
# Si la mitad de las casas vale menos de 80 y el precio mas bajo es de 72, podemos decir que la mayor parte de las casas de este barrio son baratas (habitacion compartidas o habitaciones privadas).
#
# Esto se cumple para el resto de barrios. Es decir, en todos los barrios hay más alquileres de habitaciones compartidas que apartamentos enteros.
#
# La mediana de alquileres del Barrio Hell´s Kitchen es de 127.37, mientras que, el alquiler más caro de Bushwick es de 141.56. Por tanto, podemos ver que la mitad de los alquileres del barrio más caro (Hell´s Kitchen) tienen un valor muy cercano a alquilar un apartamento entero en el barrio de Bushwick.
# El alquiler más barato de Hell´s Kitchen (81.54) tiene un precio muy similar a la mediana de alquileres de Harlem (80.07) y Williamsburg (83.48).
# Es decir, el barrio de Hell´s Kitchen es bastante más caro que el barrio de Bushwick.

# %%
# PARTE4 RESEÑAS.

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

airbnbs = pd.read_csv('./DatasetsLab1/airbnb.csv', encoding='latin-1')
airbnbs = airbnbs.dropna()


# Convertimos los valores de la columna last_review a un valor númerico de año
airbnbs["last_review"] = pd.to_datetime(airbnbs["last_review"], format="%Y-%m-%d")

# De esta forma, vemos cuantos años hay en la columna last_review.
# Es decir, para cada año veremos el numero total de reseñas y lo añadiremos a la gráfica.
anios_diferentes = airbnbs["last_review"].dt.year.unique()
anios_diferentes_ordenados = sorted(anios_diferentes)

print("Los años diferentes en la columna 'last_review' son: ")
for anio in anios_diferentes_ordenados:
    print(anio)

# El rango de fechas del archivo airbnbs lo podemos ver con el siguiente código:
fecha_min = airbnbs['last_review'].min()
fecha_max = airbnbs['last_review'].max()

# Imprimir el rango de fechas
print('El rango de fechas del archivo es desde {} hasta {}.'.format(fecha_min, fecha_max))
# Out:
# Los años diferentes en la columna 'last_review' son:
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2018
# 2019
# El rango de fechas del archivo es desde 2011-03-28 00:00:00 hasta 2019-07-08 00:00:00.

# %%
# Reseñas año 2011
res2011 = airbnbs["last_review"].dt.year == 2011
res2011 = airbnbs[res2011]
res2011.head(10)
num_filas = res2011.shape[0]
print(f'El dataset tiene {num_filas} filas.')
# Out:
# El dataset tiene 7 filas.

# %%
# Reseñas año 2012
res2012 = airbnbs["last_review"].dt.year == 2012
res2012 = airbnbs[res2012]
res2012.head(10)
num_filas = res2012.shape[0]

print(f'El dataset tiene {num_filas} filas.')
# Out:
# El dataset tiene 25 filas.

# %%
# Reseñas año 2013
res2013 = airbnbs["last_review"].dt.year == 2013
res2013 = airbnbs[res2013]
res2013.head(10)
num_filas = res2013.shape[0]

print(f'El dataset tiene {num_filas} filas.')
# Out:
# El dataset tiene 48 filas.

# %%
# Reseñas año 2014
res2014 = airbnbs["last_review"].dt.year == 2014
res2014 = airbnbs[res2014]
res2014.head(10)
num_filas = res2014.shape[0]

print(f'El dataset tiene {num_filas} filas.')
# Out:
# El dataset tiene 199 filas.

# %%
# Reseñas año 2015
res2015 = airbnbs["last_review"].dt.year == 2015
res2015 = airbnbs[res2015]
res2015.head(10)
num_filas = res2015.shape[0]

print(f'El dataset tiene {num_filas} filas.')
# Out:
# El dataset tiene 1388 filas.

# %%
# Reseñas año 2016
res2016 = airbnbs["last_review"].dt.year == 2016
res2016 = airbnbs[res2016]
res2016.head(10)
num_filas = res2016.shape[0]

print(f'El dataset tiene {num_filas} filas.')
# Out:
# El dataset tiene 2703 filas.

# %%
# Reseñas año 2017
res2017 = airbnbs["last_review"].dt.year == 2017
res2017 = airbnbs[res2017]
res2017.head(10)
num_filas = res2017.shape[0]

print(f'El dataset tiene {num_filas} filas.')
# Out:
# El dataset tiene 3203 filas.

# %%
# Reseñas año 2018
res2018 = airbnbs["last_review"].dt.year == 2018
res2018 = airbnbs[res2018]
res2018.head(10)
num_filas = res2018.shape[0]

print(f'El dataset tiene {num_filas} filas.')
# Out:
# El dataset tiene 6047 filas.

# %%
# Reseñas año 2019
res2019 = airbnbs["last_review"].dt.year == 2019
res2019 = airbnbs[res2019]
res2019.head(10)
num_filas = res2019.shape[0]

print(f'El dataset tiene {num_filas} filas.')
# Out:
# El dataset tiene 25201 filas.

# %%
plt.boxplot([price, price1, price2, price3, price4])
# Añadir título y etiquetas de los ejes
plt.title('Diagrama de cajas de todos los barrios')
#plt.xlabel('')
plt.ylabel('Precio')
plt.show()

# %%
datos = [price, price1 , price2 , price3 ,price4]
fig, ax = plt.subplots(nrows=1, ncols=5, figsize=(10, 5), sharey=True)
nombre = ['Harlem', 'Bedford', 'Hells', 'Bush' , 'William' ]
diagrama = np.array(nombre)
for i in range(5):
    ax[i].boxplot(datos[i])
    ax[i].set_title(diagrama[i].format(i+1))

# %%
# Agrupar por año y contar el número de reseñas
resenas_por_anio = airbnbs.groupby(airbnbs['last_review'].dt.year)['number_of_reviews'].count()

# Crear el diagrama de líneas
plt.plot(resenas_por_anio.index, resenas_por_anio.values)
plt.xlabel('Año')
plt.ylabel('Número de reseñas')
plt.title('Tendencia de reseñas a lo largo del tiempo')
plt.show()

# %% [markdown]
# Tal y como se refleja en el enunciado de la práctica, se intuye que la tendencia a dejar reseñas en las apps que prestan servicios, ha
# aumentado en los últimos años.
# Como podemos comprobar, esto se cumple. Es decir, hay 7 apartamentos con última reseña en 2011, hay 25 apartamentos con última reseña en 2012 y hay 48 apartamentos con última reseña en 2013.
# Es decir, los apartamentos que tienen fecha de última reseña en esos años son muy pocos, ya que, con el paso del tiempo la tendencia a dejar reseñas ha aumentado
# y la mayoría de apartamentos han obtenido reseñas recientes, y por tanto, los apartamentos con fecha de última reseñas en esos años son muy pocos.
#
# También podemos observar que la tendencia a dejar reseñas ha aumentado haciendo hicanpié en las reseñas/mes. Por ejemplo, en 2011 las reseñas/mes eran valores muy bajos, mientras que, en el año 2019
# hay apartamentos que han llegado a obtener una media de 4.64 reseñas/mes. Por tanto, esto nos muestra que la tendencia a dejar reseñas ha aumentado.

# %%
## PRUEBA

# Crear la figura y los ejes
#fig, ax = plt.subplots()


#media_2011 = res2011['reviews_per_month'].mean()

# Utilizar el método plot() para cada dataset y agregar una etiqueta en la leyenda
#media_2011.plot(ax=ax, label='2011')
#res2012['reviews_per_month'].plot(ax=ax, label='2012')
#res2013['reviews_per_month'].plot(ax=ax, label='2013')
#res2014['reviews_per_month'].plot(ax=ax, label='2014')
#res2015['reviews_per_month'].plot(ax=ax, label='2015')
#res2016['reviews_per_month'].plot(ax=ax, label='2016')
#res2017['reviews_per_month'].plot(ax=ax, label='2017')
#res2018['reviews_per_month'].plot(ax=ax, label='2018')
#res2019['reviews_per_month'].plot(ax=ax, label='2019')


# Establecer el título y las etiquetas de los ejes
#ax.set_title('Reseñas por dataset')
#ax.set_xlabel('Índice')
#ax.set_ylabel('Reseñas')

# Mostrar la leyenda y la gráfica
#ax.legend()
#plt.show()

# %%
# Calcular las medias de reseñas por año en cada uno de los DataFrames
medias = [
    res2011['reviews_per_month'].mean(),  # Media del primer dataset
    res2012['reviews_per_month'].mean(),  # Media del primer dataset
    res2013['reviews_per_month'].mean(),  # Media del primer dataset
    res2014['reviews_per_month'].mean(),  # Media del primer dataset
    res2015['reviews_per_month'].mean(),  # Media del primer dataset
    res2016['reviews_per_month'].mean(),  # Media del primer dataset
    res2017['reviews_per_month'].mean(),  # Media del primer dataset
    res2018['reviews_per_month'].mean(),  # Media del primer dataset
    res2019['reviews_per_month'].mean(),  # Media del primer dataset
    
    
]

# Crear la gráfica de barras
plt.bar(['2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019'], medias)

# Establecer el título y las etiquetas de los ejes
plt.title('Parte 4')
plt.xlabel('Años')
plt.ylabel('Media de reseñas mensuales')

# Mostrar la gráfica
plt.show()
